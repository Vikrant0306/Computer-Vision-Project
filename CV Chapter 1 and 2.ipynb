# %%
import numpy as np
import pandas as pd

# %%
import cv2
import matplotlib.pyplot as plt
import os


# Replace 'your_image.jpg' with the exact filename of your uploaded image
image_path = "/content/Lenna_(test_image).png"

# Load the color image
color_image = cv2.imread(image_path)

# Convert to grayscale
gray_image = cv2.cvtColor(color_image, cv2.COLOR_BGR2GRAY)

# Apply Canny edge detection
edges = cv2.Canny(gray_image, 100, 200)

# Display original color image and edges
plt.figure(figsize=(12,6))
plt.subplot(1,2,1)
plt.title("Original Color Image")
plt.imshow(cv2.cvtColor(color_image, cv2.COLOR_BGR2RGB))
plt.axis('off')

plt.subplot(1,2,2)
plt.title("Edges Detected (Canny)")
plt.imshow(edges, cmap='gray')
plt.axis('off')

plt.show()

# %% [markdown]
# ###UNIT 2

# %%
import cv2
import matplotlib.pyplot as plt
import os


image_path = "/content/Lenna_(test_image).png"

# Load the grayscale image
bw_image = cv2.imread(image_path, cv2.IMREAD_GRAYSCALE)

# Check if image loaded
if bw_image is None:
    print("Image not loaded. Check the path!")
else:
    print("Image loaded successfully!")

# Apply global thresholding
_, binary_global = cv2.threshold(bw_image, 127, 255, cv2.THRESH_BINARY)

# Apply Otsu's thresholding (automatic threshold selection)
_, binary_otsu = cv2.threshold(bw_image, 0, 255, cv2.THRESH_BINARY + cv2.THRESH_OTSU)

# Display results
plt.figure(figsize=(15,5))

plt.subplot(1,3,1)
plt.title("Original B/W Image")
plt.imshow(bw_image, cmap='gray')
plt.axis('off')

plt.subplot(1,3,2)
plt.title("Binary Image (Global Threshold)")
plt.imshow(binary_global, cmap='gray')
plt.axis('off')

plt.subplot(1,3,3)
plt.title("Binary Image (Otsu Threshold)")
plt.imshow(binary_otsu, cmap='gray')
plt.axis('off')

plt.show()
# Out:
# Image loaded successfully!
